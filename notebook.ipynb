# %% [markdown]
# # What's in an Avocado Toast: A Supply Chain Analysis
#
#
# ![](avocado_wallpaper.jpeg)

# %%
import pandas as pd

# %%
# Load data
avocado = pd.read_csv('data/avocado.csv', sep='\t')
avocado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1785 entries, 0 to 1784
# Columns: 184 entries, code to data_sources
# dtypes: float64(58), int64(1), object(125)
# memory usage: 2.5+ MB

# %%
# Subset the data
column = [ 'code', 'lc', 'product_name_en', 'quantity', 'serving_size', 'packaging_tags', 'brands', 'brands_tags', 'categories_tags', 'labels_tags', 'countries', 'countries_tags', 'origins','origins_tags']

avocado = avocado[column]
avocado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1785 entries, 0 to 1784
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   code             1785 non-null   object
#  1   lc               1785 non-null   object
#  2   product_name_en  1273 non-null   object
#  3   quantity         276 non-null    object
#  4   serving_size     473 non-null    object
#  5   packaging_tags   146 non-null    object
#  6   brands           674 non-null    object
#  7   brands_tags      674 non-null    object
#  8   categories_tags  752 non-null    object
#  9   labels_tags      306 non-null    object
#  10  countries        1779 non-null   object
#  11  countries_tags   1779 non-null   object
#  12  origins          58 non-null     object
#  13  origins_tags     58 non-null     object
# dtypes: object(14)
# memory usage: 195.4+ KB

# %%
# Drop rows with null categories_tags
avocado = avocado.dropna(subset='categories_tags')

# %%
# Show unique categories list
avocado['categories_tags'].unique()
# Out:
# array(['en:plant-based-foods-and-beverages,en:plant-based-foods,en:fats,en:vegetable-fats,en:vegetable-oils,en:fruit-and-fruit-seed-oils',
#        'en:snacks,en:salty-snacks,en:appetizers,en:chips-and-fries,en:crisps',
#        'de:abendbrotsufstrich',
#        'en:plant-based-foods-and-beverages,en:plant-based-foods,en:fruits-and-vegetables-based-foods,en:fruits-based-foods,en:fruits,en:tropical-fruits,en:avocados',
#        'en:plant-based-foods-and-beverages,en:plant-based-foods,en:condiments,en:spices,en:spice-mix',
#        'en:plant-based-foods-and-beverages,en:plant-based-foods,en:fruits-and-vegetables-based-foods,en:spreads,en:fruits-based-foods,en:plant-based-spreads,en:salted-spreads,en:fruits,en:tropical-fruits,en:avocados,en:avocado-pulp',
#        'en:plant-based-foods-and-beverages,en:plant-based-foods,en:legumes-and-their-products,en:legumes,en:seeds,en:spreads,en:legume-seeds,en:meals,en:plant-based-spreads,en:salted-spreads,en:pulses,en:lentils,en:lentil-spreads,en:prepared-lentils',
#        'en:plant-based-foods-and-beverages,en:plant-based-foods,en:condiments,en:spreads,en:plant-based-spreads,en:sauces,en:dips,en:guacamoles,en:groceries',
#        'en:plant-based-foods-and-beverages,en:plant-based-foods,en:condiments,en:spreads,en:plant-based-spreads,en:sauces,en:dips,en:guacamoles',
#        'en:plant-based-foods-and-beverages,en:plant-based-foods,en:spreads,en:plant-based-spreads,en:salted-spreads',
#        'en:plant-based-foods-and-beverages,en:plant-based-foods,en:fats,en:vegetable-fats,en:vegetable-oils',
#        'en:meals,en:sushis-and-makis,en:sushis',
#        'en:plant-based-foods-and-beverages,en:plant-based-foods,en:fats,en:spreads,en:plant-based-spreads,en:spreadable-fats,en:vegetable-fats,en:margarines',
#        'en:plant-based-foods-and-beverages,en:plant-based-foods',
#        'en:plant-based-foods-and-beverages,en:plant-based-foods,en:fats,en:vegetable-fats,en:vegetable-oils,en:fruit-and-fruit-seed-oils,en:avocado-oils',
#        'en:plant-based-foods-and-beverages,en:plant-based-foods,en:fruits-and-vegetables-based-foods',
#        'en:sandwiches', 'en:condiments,en:sauces,en:mayonnaises',
#        'en:plant-based-foods-and-beverages,en:plant-based-foods,en:condiments,en:spreads,en:plant-based-spreads,en:salted-spreads,en:sauces,en:dips,en:hummus',
#        'en:plant-based-foods-and-beverages,en:plant-based-foods,en:condiments,en:fats,en:vegetable-fats,en:vegetable-oils,en:sauces,en:fruit-and-fruit-seed-oils,en:avocado-oils',
#        'en:plant-based-foods-and-beverages,en:plant-based-foods,en:pastas',
#        'en:fats,en:oils',
#        'en:plant-based-foods-and-beverages,en:plant-based-foods,en:fats,en:vegetable-fats,en:vegetable-oils,en:fruit-and-fruit-seed-oils,en:avocado-oils,en:oils',
#        'en:plant-based-foods-and-beverages,en:plant-based-foods,en:nuts-and-their-products,en:nuts,en:cashew-nuts',
#        'en:avocado-oil-spray',
#        'en:snacks,en:salty-snacks,en:sweet-snacks,en:appetizers,en:biscuits-and-cakes,en:biscuits,en:crackers',
#        'en:fats,en:meats-and-their-products,en:meats,en:prepared-meats,en:cured-sausages',
#        'en:plant-based-foods-and-beverages,en:plant-based-foods,en:fats,en:vegetable-fats,en:vegetable-oils,en:fruit-and-fruit-seed-oils,en:avocado-oils,en:coconut-oils',
#        'en:condiments,en:sauces,en:groceries',
#        'en:plant-based-foods-and-beverages,en:beverages,en:plant-based-beverages,en:smoothies',
#        'en:desserts,en:frozen-foods,en:frozen-desserts',
#        'en:condiments,en:sauces,en:mayonnaises,en:groceries',
#        'en:condiments,en:sauces',
#        'en:plant-based-foods-and-beverages,en:plant-based-foods,en:fruits-and-vegetables-based-foods,en:fruits-based-foods,en:fruits,en:tropical-fruits,en:avocados,en:frucht-und-gemusebasierte-lebensmittel,en:fruchtbasierte-lebensmittel,en:fruchte,en:pflanzliche-lebensmittel,en:pflanzliche-lebensmittel-und-getranke,en:tropische-fruchte',
#        'en:condiments',
#        'en:plant-based-foods-and-beverages,en:plant-based-foods,en:spreads,en:plant-based-spreads,en:salted-spreads,de:streichcreme',
#        'en:meat-alternatives,en:vegetarian-patties,en:vegan-patties',
#        'en:plant-based-foods-and-beverages,en:plant-based-foods,en:fruits-and-vegetables-based-foods,en:fruits-based-foods,en:fruits,en:tropical-fruits,en:avocados,fr:email-80-123g',
#        'en:condiments,en:sauces,en:salad-dressings,en:groceries',
#        'en:condiments,en:sauces,en:salad-dressings',
#        'en:breakfasts,en:spreads,en:sweet-spreads,en:bee-products,en:farming-products,en:sweeteners,en:honeys',
#        'en:plant-based-foods-and-beverages,en:plant-based-foods,en:snacks,en:cereals-and-potatoes,en:salty-snacks,en:appetizers,en:chips-and-fries,en:crisps,en:potato-crisps',
#        'en:meals,en:prepared-salads',
#        'en:condiments,en:sauces,en:dips,en:salad-dressings,en:groceries',
#        'en:snacks', 'en:cooking-oil',
#        'en:plant-based-foods-and-beverages,en:plant-based-foods,en:condiments,en:fruits-and-vegetables-based-foods,en:spreads,en:fruits-based-foods,en:plant-based-spreads,en:fruits,en:sauces,en:tropical-fruits,en:dips,en:avocados,en:guacamoles',
#        'en:plant-based-foods-and-beverages,en:plant-based-foods,en:spreads,en:plant-based-spreads,en:salted-spreads,en:vegan-vegetable-spreads',
#        'en:plant-based-foods-and-beverages,en:plant-based-foods,en:fruits-and-vegetables-based-foods,en:fruits-based-foods,en:fruits,en:tropical-fruits,en:avocados,en:fresh-avocados',
#        'en:plant-based-foods-and-beverages,en:plant-based-foods,en:fruits-and-vegetables-based-foods,en:fruits-based-foods',
#        'en:plant-based-foods-and-beverages',
#        'en:condiments,en:sauces,en:dips,en:groceries',
#        'en:dairies,en:fats,en:spreads,en:spreadable-fats,en:animal-fats,en:milkfat,en:dairy-spread,en:butters,en:salted-butters',
#        'en:condiments,en:sauces,en:dips',
#        'en:plant-based-foods-and-beverages,en:spreads', 'en:fats',
#        'en:plant-based-foods-and-beverages,en:plant-based-foods,en:fats,en:vegetable-fats,en:vegetable-oils,en:fruit-and-fruit-seed-oils,en:coconut-oils',
#        'en:snacks,en:sweet-snacks,en:biscuits-and-cakes',
#        'en:snacks,en:salty-snacks,en:appetizers,en:chips-and-fries,en:crisps,en:corn-chips',
#        'en:plant-based-foods-and-beverages,en:plant-based-foods,en:fats,en:vegetable-fats,en:vegetable-oils,en:fruit-and-fruit-seed-oils,en:avocado-oils,en:cold-presses-avocado-oil',
#        'en:condiments,en:sauces,en:hot-sauces',
#        'en:condiments,en:fats,en:sauces,en:mayonnaises,en:groceries',
#        'en:plant-based-foods-and-beverages,en:plant-based-foods,en:fruits-and-vegetables-based-foods,en:fruits-based-foods,en:fruits,en:tropical-fruits,en:avocados,en:avocadoes,en:salads',
#        'en:plant-based-foods-and-beverages,en:plant-based-foods,en:fruits-and-vegetables-based-foods,en:frozen-foods,en:vegetables-based-foods,en:frozen-plant-based-foods,en:frozen-vegetables',
#        'en:plant-based-foods-and-beverages,en:plant-based-foods,en:fats,en:vegetable-fats,en:vegetable-oils,en:fruit-and-fruit-seed-oils,en:avocado-oils,en:oil,en:oils',
#        'en:plant-based-foods-and-beverages,en:plant-based-foods,en:fruits-and-vegetables-based-foods,en:frozen-foods,en:fruits-based-foods,en:specific-products,en:frozen-plant-based-foods,en:fruits,en:products-for-specific-diets,en:products-without-gluten,en:tropical-fruits,en:frozen-fruits,en:avocados,en:frozen-tropical-fruits,en:frozen-avocados',
#        'en:plant-based-foods-and-beverages,en:plant-based-foods,en:spreads,en:plant-based-spreads',
#        'en:plant-based-foods-and-beverages,en:plant-based-foods,en:condiments,en:fats,en:vegetable-fats,en:vegetable-oils,en:sauces,en:groceries',
#        'en:meals',
#        'en:plant-based-foods-and-beverages,en:plant-based-foods,en:fruits-and-vegetables-based-foods,en:fruits-based-foods,en:fruits,en:tropical-fruits,en:avocadoes',
#        'en:plant-based-foods-and-beverages,en:plant-based-foods,en:meat-alternatives,en:meat-analogues,en:vegetarian-patties',
#        'en:masque-visage', 'en:condiments,en:sauces,en:tzatzikis',
#        'en:desserts,en:frozen-foods,en:frozen-desserts,en:ice-creams-and-sorbets,en:ice-creams,en:sundae-ice-cream',
#        'en:plant-based-foods-and-beverages,en:plant-based-foods,en:fruits-and-vegetables-based-foods,en:fruits-based-foods,en:fruits',
#        'en:condiments,en:sauces,en:salad-dressings,en:vinaigrettes,en:groceries,fr:vinaigrettes-au-sesame',
#        'en:groceries', 'en:sandwiches,en:wraps,en:chicken-wraps',
#        'en:dairies,en:fermented-foods,en:fats,en:fermented-milk-products,en:cheeses',
#        'en:plant-based-foods-and-beverages,en:plant-based-foods,en:condiments,en:spreads,en:plant-based-spreads,en:sauces,en:dips,en:guacamoles,en:spicy-guacamoles,en:groceries',
#        'en:meals,en:sushis-and-makis,en:sushis,en:sushi-medley',
#        'en:plant-based-foods-and-beverages,en:plant-based-foods,en:fruits-and-vegetables-based-foods,en:vegetables-based-foods,en:fresh-foods,en:fresh-plant-based-foods,en:fresh-vegetables',
#        'en:frozen-foods,en:meals,en:frozen-ready-made-meals',
#        'en:meals,en:prepared-salads,en:mexican-salads,en:salads',
#        'en:beverages,en:artificially-sweetened-beverages,en:diet-beverages,en:tea-based-beverages,en:iced-teas,en:light-iced-teas',
#        'en:spreads,en:spreadable-fats',
#        'en:plant-based-foods-and-beverages,en:plant-based-foods,en:fats,en:fruits-and-vegetables-based-foods,en:fruits-based-foods,en:vegetable-fats,en:vegetable-oils,en:fruit-and-fruit-seed-oils,en:avocado-oils',
#        'en:plant-based-foods-and-beverages,en:plant-based-foods,en:condiments,en:spreads,en:plant-based-spreads,en:sauces,en:dips,en:guacamoles,en:groceries,en:guacamole-dip',
#        'en:plant-based-foods-and-beverages,en:plant-based-foods,en:fruits-and-vegetables-based-foods,en:vegetables-based-foods,en:tomatoes-and-their-products',
#        'en:meals,en:sushis-and-makis,en:sushis,en:avocado-and-salmon-sushis',
#        'en:plant-based-foods-and-beverages,en:beverages,en:plant-based-beverages,en:smoothies,en:fruit-smoothies',
#        'en:breakfasts,en:spreads,en:sweet-spreads,en:bee-products,en:farming-products,en:sweeteners,en:honeys,en:raw-honey',
#        'en:plant-based-foods-and-beverages,en:plant-based-foods,en:fruits-and-vegetables-based-foods,en:fruits-based-foods,en:fruits,en:tropical-fruits',
#        'en:90',
#        'en:plant-based-foods-and-beverages,en:plant-based-foods,en:seafood,en:cereals-and-potatoes,en:fishes,en:cereals-and-their-products,en:meals,en:meals-with-fish,en:pastas',
#        'it:tramezzini-al-salmone,it:tramezzini-con-salmone,it:tramezzini-salmone',
#        'en:plant-based-foods-and-beverages,en:plant-based-foods,en:fruits-and-vegetables-based-foods,en:fruits-based-foods,en:fruits,en:tropical-fruits,en:avocados,en:raw-green-avocados',
#        'en:condiments,en:sauces,en:hot-sauces,en:groceries',
#        'en:meats-and-their-products,en:meats,en:chicken-and-its-products,en:poultries,en:chickens',
#        'en:desserts,en:frozen-foods,en:frozen-desserts,en:ice-creams-and-sorbets,en:ice-creams',
#        'en:plant-based-foods-and-beverages,en:plant-based-foods,en:meals,en:prepared-vegetables,en:purees,en:mashed-vegetables',
#        'en:plant-based-foods-and-beverages,en:plant-based-foods,en:condiments,en:spreads,en:plant-based-spreads,en:salted-spreads,en:sauces,en:dips,en:hummus,de:vegan',
#        'en:plant-based-foods-and-beverages-plant-based-foods-fats-vegetable-fats-vegetable-oils-fruit-and-fruit-seed-oils-avocado-oils',
#        'en:meals,en:sushis-and-makis,en:makis,en:sushis,en:avocado-and-salmon-sushis',
#        'en:frozen-foods', 'de:fingerfood',
#        'en:plant-based-foods-and-beverages,en:plant-based-foods,en:fats,en:spreads,en:plant-based-spreads,en:salted-spreads,en:spreadable-fats,en:vegetable-fats,en:margarines,en:light-margarines',
#        'en:plant-based-foods-and-beverages,en:plant-based-foods,en:fruits-and-vegetables-based-foods,en:frozen-foods,en:fruits-based-foods,en:frozen-plant-based-foods,en:fruits,en:tropical-fruits,en:frozen-fruits,en:avocados,en:frozen-tropical-fruits,en:frozen-avocados',
#        'en:meals,en:prepared-salads,en:salads', 'en:salted-snacks',
#        'en:meals,en:sandwiches,en:sushis-and-makis,en:sushis',
#        'en:plant-based-foods-and-beverages,en:plant-based-foods,en:fruits-and-vegetables-based-foods,en:frozen-foods,en:fruits-based-foods,en:vegetables-based-foods,en:frozen-plant-based-foods,en:frozen-vegetables',
#        'en:plant-based-foods-and-beverages,en:plant-based-foods,en:fats,en:vegetable-fats',
#        'en:dairies,en:fermented-foods,en:desserts,en:fermented-milk-products,en:dairy-desserts,en:fermented-dairy-desserts,en:yogurts',
#        'en:seafood,en:frozen-foods,en:frozen-seafood',
#        'en:plant-based-foods-and-beverages,en:beverages,en:plant-based-beverages',
#        'en:baking-decorations',
#        'en:plant-based-foods-and-beverages,en:plant-based-foods,en:condiments,en:spreads,en:plant-based-spreads,en:salted-spreads,en:sauces,en:dips,en:hummus,en:groceries',
#        'en:plant-based-foods-and-beverages,en:plant-based-foods,en:frozen-foods,en:frozen-plant-based-foods,en:frozen-plant-based-foods-mixes',
#        'en:plant-based-foods-and-beverages,en:plant-based-foods,en:condiments,en:groceries',
#        'en:sandwiches,en:poultry-sandwiches,en:chicken-sandwiches',
#        'en:plant-based-foods-and-beverages,en:plant-based-foods,en:fruits-and-vegetables-based-foods,en:fruits-based-foods,en:fruits,en:tropical-fruits,en:avocados,fr:hass-avocados'],
#       dtype=object)

# %%
# Splitting the comma seperated tags to column of list
avocado['categories_list'] = avocado['categories_tags'].str.split(',')

# %%
# Identify relevant categories
relevant_categories = ['en:avocadoes', 
                       'en:avocados', 
                       'en:fresh-foods', 
                       'en:fresh-vegetables', 
                       'en:fruchte', 
                       'en:fruits', 
                       'en:raw-green-avocados', 
                       'en:tropical-fruits', 
                       'en:tropische-fruchte', 
                       'en:vegetables-based-foods',
                       'fr:hass-avocados'
                      ]

# Filter data bases on relevant categories
avocado = avocado[avocado['categories_list'].apply(lambda x: any([i for i in x if i in relevant_categories]))]
avocado['categories_list'].head()
# Out:
# 5     [en:plant-based-foods-and-beverages, en:plant-...
# 6     [en:plant-based-foods-and-beverages, en:plant-...
# 14    [en:plant-based-foods-and-beverages, en:plant-...
# 17    [en:plant-based-foods-and-beverages, en:plant-...
# 23    [en:plant-based-foods-and-beverages, en:plant-...
# Name: categories_list, dtype: object

# %%
# Filter UK
avocados_uk = avocado[avocado['countries'] == 'United Kingdom']

avocados_uk['origins_tags'].value_counts()
avocado_origin = 'Peru'

# %%
# Creating function to repeat for another dataset
def read_and_filter_data(filepath, relevant_categories):
  df = pd.read_csv('data/' + filepath, sep='\t')

  # Subset data
  df = df[column]

  # Split tags into lists
  df['categories_list'] = df['categories_tags'].str.split(',')

  # Drop null categories and filter data
  df = df.dropna(subset = 'categories_list')
  df = df[df['categories_list'].apply(lambda x: any([i for i in x if i in relevant_categories]))]
  df = df[(df['countries']=='United Kingdom')]
  print(f'**{filepath[:-4]} origins**','\n',df['origins_tags'].value_counts(), '\n')
  return df

# %%
# Lemon top supply
relevant_lemon_categories = ['en:aromatic-plants', 
                             'en:citron', 
                             'en:citrus', 
                             'en:fresh-fruits', 
                             'en:fresh-lemons', 
                             'en:fruits', 
                             'en:lemons', 
                             'en:unwaxed-lemons'
                            ]

lemon = read_and_filter_data('lemon.csv', relevant_lemon_categories)
lemon_origin = 'South Africa'
# Out:
# **lemon origins**
#  en:brazil,en:south-africa    1
# en:south-africa              1
# Name: origins_tags, dtype: int64

# %%
# Olive oil top supply
with open("data/relevant_olive_oil_categories.txt", "r") as file:
    relevant_olive_oil_categories = file.read().splitlines()
    file.close()
    
olive_oil = read_and_filter_data('olive_oil.csv', relevant_olive_oil_categories)
olive_oil_origin = 'Greece'
# Out:
# **olive_oil origins**
#  en:greece                                             6
# en:spain                                              4
# en:italy                                              4
# en:greece,en:italy,en:portugal,en:spain,en:tunisia    2
# en:produce-of-italy                                   1
# en:european-union-and-non-european-union              1
# en:produced-in-italy                                  1
# en:european-union                                     1
# Name: origins_tags, dtype: int64

# %%
# Sourdough top supply
with open("data/relevant_sourdough_categories.txt", "r") as file:
    relevant_sourdough_categories = file.read().splitlines()
    file.close()
    
sourdough = read_and_filter_data('sourdough.csv', relevant_sourdough_categories)
sourdough_origin = 'United Kingdom'
# Out:
# **sourdough origins**
#  en:united-kingdom    3
# en:france            1
# Name: origins_tags, dtype: int64

# %%
# Salt top supply
relevant_salt_categories = [
 'en:edible-common-salt',
 'en:salts',
 'en:sea-salts',]

salt_flakes = read_and_filter_data('salt_flakes.csv', relevant_salt_categories)
# Out:
# **salt_flakes origins**
#  Series([], Name: origins_tags, dtype: int64)
